# %% [markdown]
# ## Synchronizing data across streams: clock calibration, synchronization signals, TPrime
#
# The sample clocks for Neuropixels probes are located on the headstages. As a result:
#
#  - auxiliary data (from NI and OneBox) is collected on a different clock
#  - probes plugged into other headstages are on separate clocks
#
# as a result, the data are **asynchronous.** In addtion, the clock rates are unknown and can drift over time.
#
# To look at the impact this has on data, and some different ways to synchronize probe data with OneBox analog channels, we'll analyze a long dataset with a repeating signal. These data were acquired by generating a bipolar pulse using the OneBox analog output, connecting that to a saline bath and measuring it with an NP2.0 probe. This is a variant of the gain test described in the Neuropixels manual.
#
# Open the run /sync_example/bipolar_uncal_sync_test_g0 in the SpikeGLX file viewer (in SGLX: File->Open File Viewer, and select either binary, the probe or obx).
# Use File->Link to open the other binary. This also links the time scrolling for the two files. In the obx file, set the YScale to 400 to see the 5 mV input pulses.
#
# Looking at the start of the file, the waveforms are aligned; looking 8 hours later, they are offset by 0.3 sec (!). (to select a portion of hte recording in the viewer: shift + click and drag -- the corresponding time is selected in the other streams).
#
# ![Test recording at 0 and 8 hours](sync_8hr_.png)
#
# This offset is not due to changes in the clock rates, but rather that the clock rates for the two streams differ from the nominal values. The 1 Hz sine wave sync signal can be used to get a better measurement of the actual rate. Go to SpikeGLX Tools->Sample Rates from Run, check the box for all streams, and hit go. The output is measured rates for the two steams:
# ![Sample rates from run](sync_example_sample_rates.png)
#
# If you select apply, these rates will be written to the metadata for the run. If you close and reopen the run, you'll see those rates in title bar for the run, and both the sync traces and the probe data will be aligned, and these new rates will be used in any further analysis.
#
# The clock rates are also stored in the _Calibrations folder of SpikeGLX, and will be applied next time you do a run with those devices. The best practice is to calibrate clocks before running -- all that is needed is a probe plugged into the headstage. Select 'Use next run for calibration' in the Sync tab of SpikeGLX to do a calibration run.

# %% [markdown]
# ### How large is the offset between streams for a given error in the assumed clock rates?
#
# For simplicity: assume the rate for the OneBox is exactly its nominal rate: 30303 Hz
# Assumed headstage clock rate = 30000 Hz
# Real headstage clock rate = 30000 Hz (nominal) + error
#
# The times in the two streams are calculated from assumed sample rate. What's the error in the calculated time in the probe stream after some hours?
#
# Note that real rates of the headstage clocks can be off by up to 0.5 Hz. Measurement error when deriving the rate from a relatively short dataset (40 min) can still be up as large as 0.05 Hz.

# %%
import matplotlib.pyplot as plt
import numpy as np
import readSGLX
import os
from pathlib import Path

recording_min = 240
hs_clock_err_hz = -0.2
hs_assumed_rate_hz = 30000

tpts = np.arange(recording_min)
tpts = tpts*60

# error = real time - calculated time = t - # samples recorded/assumed sample rate = t - t*(real sample rate)/(assumed sample rate)
err = 1000*(tpts*(1- (hs_assumed_rate_hz + hs_clock_err_hz)/hs_assumed_rate_hz ))

plt.plot(tpts, err)
plt.xlabel('Time in recording (sec)')
plt.ylabel('error in calculated time (msec)')

# %% [markdown]
# ### Measuring residual timing errors after calibration
#
# The synchronization edges are simultaneous. We can measure how large error is using a single rate for the entire run for each edge in the dataset.
#
# To do this from scratch, run CatGT to extract the sync edges from both streams. A sample .bat file to run CatGT is included in the download. The command line is:
#
# ``CatGT -dir=D:/sync_example -run=bipolar_uncal_ob89_sync -g=0 -t=0 -prb_fld -ob -ap -obx=0 -prb=0 -no_tshift -xa=1,0,0,0.005,0.006,10 -dest=D:/sync_example``
#
# For the example data, this has been run. Next we load those output files (text files of the calculated times in seconds, using the best estimate of the rate calculated by 'Sample rates from run), and calculate the difference in between these times.

# %%
# set paths to output
parentFolder = Path(r'D:\sync_example')  # edit to the location on your system
runFolderName = 'bipolar_uncal_ob89_sync_g0'
obx_edges_path = parentFolder.joinpath(f'catgt_{runFolderName}',f'{runFolderName}_tcat.obx0.obx.xd_1_6_500.txt')
imec0_edges_path = parentFolder.joinpath(f'catgt_{runFolderName}',f'{runFolderName}_tcat.imec0.ap.xd_1_6_500.txt')
with open(obx_edges_path, 'r') as file:
    obx_list = file.readlines()
obx_edge_times = np.array(obx_list, dtype=float)
with open(imec0_edges_path, 'r') as file:
    imec0_list = file.readlines()
imec0_edge_times = np.array(imec0_list, dtype=float)

edge_diff = 1000*(obx_edge_times - imec0_edge_times)

plt.plot(obx_edge_times, edge_diff)
plt.xlabel('Time in recording (sec)')
plt.ylabel('diff in edge times (msec)')

# %% [markdown]
# ### Measuring residual timing errors of real events
#
# The last cell calculated the differences in times of the synchronization edges, i.e. the 1 Hz square wave generated by the OneBox and recordd in the obx and imec streams. For real data, we want the exact times of events -- usually spikes -- detected on the probes relative to experiment variables measured on the auxiliary analog inputs. In this case, we have the input signal to the buffer measured in OneBox channel 0, and the same signal is detected through the probe on channel 0 of the imec0 stream. The CatGT command line above extracted these events in the OneBox stream with the extractor (-xa=1,0,0,0.005,0.006,10). The next cell detects these events in the imec0 stream.
#
# This code uses readSGLX from this [repo](https://github.com/jenniferColonell/SpikeGLX_Datafile_Tools)

# %%
runFolder = parentFolder.joinpath(runFolderName)
imecFullPath = runFolder.joinpath(f'{runFolderName}_imec0',f'{runFolderName}_t0.imec0.ap.bin')

voltage_thresh = 0.003  # in volts

# Use the functions in readSGLX to read the imec0 analog channel and extract the positive going edges
imec_meta = readSGLX.readMeta(imecFullPath)
imec_sRate = readSGLX.SampRate(imec_meta)
imecRaw = readSGLX.makeMemMapRaw(imecFullPath, imec_meta)

# to keep this faster, analyze the data without converting to volts.
# get the scale factor from the metadata
imec_gain = float(imec_meta['imChan0apGain'])
imec_fint2V = readSGLX.Int2Volts(imec_meta)/imec_gain

imec_thresh_bits = np.floor(voltage_thresh/imec_fint2V).astype(int)

# Efficient approach for large datasets (from Gemini):
# Find indices where current is low and next is high
# Note that this doesn't include any debounce checks
rising_edges = np.where((imecRaw[0,:-1] <= imec_thresh_bits) & (imecRaw[0,1:] > imec_thresh_bits))[0] + 1
imec_event_times_sec = rising_edges/imec_sRate
imecRaw.flush

print(imec_event_times_sec.shape)
print(imec_event_times_sec[0:10])

# %%
# save the pulse times to files for TPrime
output_folder = parentFolder.joinpath('detected_events')
if not os.path.exists(output_folder):
    os.mkdir(output_folder)
np.savetxt(output_folder.joinpath('imec0_events.txt'),imec_event_times_sec,delimiter=',')

# load in the obx event times from the catgt output
obx_events_path = parentFolder.joinpath(f'catgt_{runFolderName}',f'{runFolderName}_tcat.obx0.obx.xa_0_10.txt')
with open(obx_events_path, 'r') as file:
    obx_list = file.readlines()
obx_event_sec = np.array(obx_list, dtype=float)

# plot differeces in detected event times
event_diff = 1000*(obx_event_sec - imec_event_times_sec)

plt.plot(obx_event_sec, event_diff)
plt.xlabel('Time in recording (sec)')
plt.ylabel('diff in detected event times (msec)')

# %% [markdown]
# ## What causes the remaining error?
#
# The clock rates aren't perfectly constant -- this is generally only visible in very long recordings. The average rate can be estimated (very well) by a linear fit to the times of the sync edges, but there are small fluctuations. Since small errors in the rates accumulate in the calculated time, this can result in measureable errors. Looking at the data using the corrected sample rates at ~5000 seconds, we can see that the calculated times for the pulses in the two streams are offset, but the time to the nearest sync edge is correct:
#
# ![offset at 5000sec](pulse_displacement_5000sec.png)
#
# ### SGLX + TPrime
# To map event times with sub-miillisecond accuracy across the streams, e.g. from the OneBox to the imec0 clock, TPrime:
# finds the nearest known **simultaneous** event -- the nearest SYNC edge
# calculates the time from that edge to the a time of interest (e.g. a stimulus on), by counting samples in the OneBox stream
# translates that to the time in the imec0 clock using the measured sample rates. The output is a set of times for the stimulus events, expressed in the imec0 clock -- these would be used for measuring correlation of spikes (for example) with the stimulus.
# Clock calibration in SpikeGLX and TPrime are discussed in more detail [here.](https://billkarsh.github.io/SpikeGLX/help/syncEdges/Sync_edges/)

# %% [markdown]
# ## Running TPrime on this dataset
# The TPrime command line specifies the paths to the sync edges (extracted by CatGT or any other means), paths to text files of the events that need to be to be translated to the reference clock. These paths are all given in the CatGT fyi file, so the TPrime command can be built by simply copying them. For this run, the paraemters are:
#
# ``-syncperiod=1.0 ^
# -tostream=D:/sync_example/catgt_bipolar_uncal_ob89_sync_g0/bipolar_uncal_ob89_sync_g0_tcat.obx0.obx.xd_1_6_500.txt ^
# -fromstream=7,D:/sync_example/catgt_bipolar_uncal_ob89_sync_g0/bipolar_uncal_ob89_sync_g0_tcat.imec0.ap.xd_1_6_500.txt ^
# -events=7,D:\sync_example\detected_events\imec0_events.txt,D:\sync_example\detected_events\imec0_events_adj.txt  ``
#
# NOTES:
# + The carets are line continuations in BASH
# + The -events option takes three parameters: the fromstream index, the path the event times, in seconds calculated using the fromstream clock, and the path for the output.
# + A .bat file to run TPrime with this command line is included. If you run CatGT on the data, the new fyi file will have the correct paths
#
# TPrime has been run on this data, and the ouput file imec0_events_adj.txt is available. The next cell plots the difference bewteen the input edges measured in the OneBox stream and the adjusted ime0 event times output by TPrime.
#
# Result: the average difference is -0.04 ms, which is the lag between presenting the signal and detecting it on the probe. The maximimum excursion from that mean is 0.064, which is an error of two samples.

# %%
imec0_adj_path = parentFolder.joinpath('detected_events','imec0_events_adj.txt')
with open(imec0_adj_path, 'r') as file:
    adj_list = file.readlines()
imec0_event_adj = np.array(adj_list, dtype=float)

# plot differeces in detected event times
corr_event_diff = 1000*(obx_event_sec - imec0_event_adj)

print(f'Mean difference in times in ms: {np.mean(corr_event_diff):.3f}')
max_error = np.max(np.abs(corr_event_diff-np.mean(corr_event_diff)))
print(f'Maximum excursion from mean: {max_error:.3f}')

plt.plot(obx_event_sec, corr_event_diff)
plt.xlabel('Time in recording (sec)')
plt.ylabel('diff in detected event times after correction (msec)')

# %% [markdown]
# ### Open Ephys Synchronization
# OEP generates a file of timestamps for each stream in the recording, continuously correcting for the difference in sample rates by measuring the number of samples between the last two SYNC transitions in the two streams. The OEP calibration is documented [here.](https://open-ephys.github.io/gui-docs/Tutorials/Data-Synchronization.html)
#
# The critical point in both of these techniques is that they make a correction based on simultaneous events that are close in time to the mapped times. This limits errors due to imperfectly known sample rates.
